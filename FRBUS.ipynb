# %% [markdown]
# # An interactive notebook with the FRB/US model
# This notebook is based on the the FRB/US model packages located here https://www.federalreserve.gov/econres/us-models-package.htm. The packages provides an Eviews https://www.eviews.com/ implementation. The Eviews modelspecification has been transformed to ModelFlow BusinessLogic specification.
#
# You can experiment with the model using a simple interactive interface.
#
# FRB/US comes in two flawors: **VAR** in which expectaions are generated by backward looking equations, and **MCE** in which expectation are based on leaded values.
# This notebook implement the **VAR** flavour.
#
# The tool used is highly experimental and the results are purely for illustration.
#
# You can run each cell by pressing the run tool or shift+enter
# To run all cells use select cell/run all in the menu bar.

# %% [markdown]
# # Import Python libraries

# %%
# %matplotlib inline

from modelclass import model
import modelmf
model.modelflow_auto()
# Out:
#             <style>
#                 div#notebook-container    { width: 95%; }
#                 div#menubar-container     { width: 65%; }
#                 div#maintoolbar-container { width: 99%; }
#             </style>
#             <script>
#                 // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#                 require(
#                     ['base/js/namespace', 'jquery'],
#                     function(jupyter, $) {
#                         $(jupyter.events).on('kernel_ready.Kernel', function () {
#                             console.log('Auto-running all cells-below...');
#                             jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                             jupyter.actions.call('jupyter-notebook:save-notebook');
#                         });
#                     }
#                 );
#             </script>

# %% [markdown]
# # Load the model and run a  baseline

# %%
mfrbus, basedf =  model.modelload('models/frbus_var.pcim')
res = mfrbus(basedf,'2021q1','2030q4',silent=1,stats=0,ljit=1,stringjit=0)
# Out:
# Compile prolog: 100%|███████████████████████████████████████████████████████████████████████████| 3/3  2.76s/code chunk
# Compile core  : 100%|███████████████████████████████████████████████████████████████████████████| 5/5  2.30s/code chunk
# Compile epilog: 100%|███████████████████████████████████████████████████████████████████████████| 3/3  1.87s/code chunk

# %% [markdown]
# # Define an interactive input widget
# This widget allows you to input

# %%
slidedef = {'Initial taylor':                {'var':'RFFINTAY_AERR','value':0.0,'min':-3, 'max':3,'op':'+'},
            'Initial taylor inital impulse': {'var':'RFFINTAY_AERR','value':0.0,'min':-3, 'max':3,'op':'+impulse'},
            'Minimum federal funds':         {'var':'RFFMIN',       'value':0.0,'min':-20,'max':5,'op':'='       ,'step':1.0}
            }
radiodef = {'Monetary policy reaction':
            [['Inertial Taylor rule','DMPINTAY'],
             ['Taylor rule','DMPTAY'],
             ['Taylor rule with unemployment gap','DMPTLR'],
             ['Estimated rule','DMPALT'],
             ['Generalized rule','DMPGEN'],
             ['Exogenous nominal funds rate', 'DMPEX'],
             ['Exogenous real funds rate', 'DMPRR']
            ]
           }
           
checkdef = [('Timing of zero lower bound', 'DMPTRSH' ,True) ]

input = mfrbus.inputwidget('2021q1','2030q4',slidedef=slidedef,checkdef=checkdef,radiodef=radiodef
                   ,showout=True,varpat='RFF XGDPN RFFMIN GFSRPN DMPTRSH',trans=mfrbus.var_description)
# Out:
# VBox(children=(HBox(children=(Label(value='Input new parameter ', layout=Layout(width='52%')), Label(value='Al…
# VBox(children=(Tab(children=(VBox(children=(Tab(children=(Output(), Output(), Output(), Output()), _titles={'0…

# %% [markdown]
# # Try effect of different policy assumptions
# Interest rate are given a negative impulse of 2 percent. Then the model is run with different assumptions
# regarding monetary policy rule.
#
# After the experiments are run, the results are displayed in a widget which allows the user to
# select variables and different options - thy it out

# %%
newbasedf = basedf.copy()                     # make a new dataframe
mfrbus.basedf = newbasedf 


# Define the experiment
experiments = [
  ['Inertial Taylor rule', 'DMPINTAY'],
  ['Taylor rule', 'DMPTAY'],
  ['Taylor rule with unemployment gap', 'DMPTLR'],
  ['Estimated rule', 'DMPALT'],
  ['Generalized rule', 'DMPGEN'],
  ['Exogenous nominal funds rate', 'DMPEX'],
  ['Exogenous real funds rate', 'DMPRR']]

newbasedf.loc[:,[v for e,v in experiments]]=0 # Set all policy dummies to 0

for experiment,var in experiments:            # loop over the policy options and update 
    altdf=newbasedf.mfcalc(f'''\
          rffintay_aerr = rffrule_aerr - 2       
          rffmin        = 0.0        
          {var} = 1
    ''','2022q1','2022q1')
    print(f'Simulating {experiment}')
    result = mfrbus(altdf,'2020q1','2032q4',keep=f'Monetary policy rule:{experiment}',alfa=0.5,max_iterations=300)

mfrbus.keep_viz('rff xgdp rg10p',legend = True)
# Out:
# Simulating Inertial Taylor rule
# Simulating Taylor rule
# Simulating Taylor rule with unemployment gap
# Simulating Estimated rule
# Simulating Generalized rule
# Simulating Exogenous nominal funds rate
# Simulating Exogenous real funds rate
# VBox(children=(HBox(children=(SelectMultiple(description='Select one or more', index=(559, 758, 591), layout=L…
# Output()

# %% [markdown]
# # The input to equations can be traced back.
# and also the propagation of results can be traced.
#
# Displaying the graph below can depend on the browser.
# You can try to increase the size parameters
# if the complete picture is not shown.
#
# The values of the baseline and last run is displayed if **all=True** if **all=False** only the variable names are shown
#
# The **up** and **down** parameters determines how many logical levels are shown. Take care the graph can get complicated.

# %%
with mfrbus.set_smpl('2021q1','2025q2'):
    mfrbus.rffgen.draw(up=1,down=0,HR=0,all=True,svg=1,png=0,size=(10,10),filter=0)

# %% [markdown]
# # The input to equations can be traced back and filtert.
# This way we only look at significant input
#
# The values of the baseline and last run is displayed if **all=True** if **all=False** only the variable names are shown
#
# The **up** and **down** parameters determines how many logical levels are shown. Take care the graph can get complicated.

# %%
with mfrbus.set_smpl('2021q1','2023q2'):
    mfrbus.rffgen.draw(up=6,down=0,HR=1,all=True,svg=1,png=0,size=(20,20),filter=20)
